# %% [markdown]
# ### Etapas do projeto

# %% [markdown]
#  <h4> Banco de Dados e Conexão</h4>
#   <label><input type="checkbox" checked> Configuração do PostgreSQL</label><br>
#   <label><input type="checkbox" checked> Sistema de conexão por operação</label><br>
#   <label><input type="checkbox"> Criar todas as tabelas no banco</label><br>
#   <label><input type="checkbox"> Configurar relacionamentos entre tabelas</label><br>
#
#   <h4> Entidades</h4>
#   <label><input type="checkbox" checked> Classe Mestre</label><br>
#   <label><input type="checkbox"  checked> Classe Jogador</label><br>
#   <label><input type="checkbox"  checked> Classe Mesa</label><br>
#   <label><input type="checkbox"  checked> Classe Personagem</label><br>
#   <label><input type="checkbox"  checked> Classe Sistema</label><br>
#
#   <h4> DAO (Data Access Object)</h4>
#   <label><input type="checkbox" checked> Classe base DAO</label><br>
#   <label><input type="checkbox" checked> MestreDAO</label><br>
#   <label><input type="checkbox"> JogadorDAO</label><br>
#   <label><input type="checkbox"> MesaDAO</label><br>
#   <label><input type="checkbox"> PersonagemDAO</label><br>
#   <label><input type="checkbox"> SistemaDAO</label><br>
#
#   <h4> Interface de Usuário (CLI)</h4>
#   <label><input type="checkbox"> Menu principal</label><br>
#   <label><input type="checkbox"> CRUD de Mestres</label><br>
#   <label><input type="checkbox"> CRUD de Jogadores</label><br>
#   <label><input type="checkbox"> CRUD de Mesas</label><br>
#   <label><input type="checkbox"> CRUD de Personagens</label><br>
#   <label><input type="checkbox"> CRUD de Sistemas</label><br>
#   <label><input type="checkbox"> Relatórios e consultas</label><br>
#
#   <h4> Configuração do Projeto</h4>
#   <label><input type="checkbox"> requirements.txt completo</label><br>
#   <label><input type="checkbox"> Configuração do ambiente virtual</label><br>
#   <label><input type="checkbox"> Script de inicialização do banco</label><br>
#   <label><input type="checkbox"> Documentação básica</label><br>
# </div>

# %% [markdown]
# ### Descrição do projeto
